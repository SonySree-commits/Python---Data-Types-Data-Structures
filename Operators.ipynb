# %%
a=90
b=12
c=a+b
print(a,b,a+b)
print('this is a,b,a+b',a,b,a+b)
print('this is a: {},b: {},c:{}'.format(a,b,a+b))
print('this is a: {2},b: {0},c:{1}'.format(b,a+b,a))
print(f'this is a: {a},b: {b},c:{c}')
# Out:
# 90 12 102
# this is a,b,a+b 90 12 102
# this is a: 90,b: 12,c:102
# this is a: 90,b: 12,c:102
# this is a: 90,b: 12,c:102

# %%
a=123
b=7
a/b #division
# Out:
# 17.571428571428573

# %%
a=123
b=7
a//b  # gives floor value
# Out:
# 17

# %%
a=123
b=3
a%b  # gives the remainder
# Out:
# 0

# %%
a=12
b=5
a*b #multiplies
# Out:
# 60

# %%
#logical operators
#and, or, not
#and
a=12
b=0
a and b
b and a
# Out:
# 0

# %%
# if any 1 input is true then it give sthe output and gives the last givben value 
#ex: a and b gives the value of b
a=12
b='sony'
a and b
# Out:
# 'sony'

# %%
a=12
b='sony'
b and a
# Out:
# 12

# %%
a= True
b= False
a and b
# Out:
# False

# %%
a= False
b='sony'
a and b
# Out:
# False

# %%
a= False
b='sony'
b and a
# Out:
# False

# %%
#or operator
# if any 1 input is true gives the value of the first given variable
#ex: a or b gives b value as the output
a= True
b='sony'
a or b
# Out:
# True

# %%
a= False
b= True
a or b
# Out:
# True

# %%
a=0
b=45
a or b
# Out:
# 45

# %%
a= False
b='sony'
b or a
# Out:
# 'sony'

# %%
b="sree"
a='sony'
b or a
# Out:
# 'sree'

# %%
b="sree"
a='sony'
a or b
# Out:
# 'sony'

# %%
#not operator 
# gives opposite of the input
a="sony"
not a
# Out:
# False

# %%
a= True
not a
# Out:
# False

# %%
a=False
not a
# Out:
# True

# %%
#relation operator :>,<,>=,<=,==,!=

a=45
b=2
print(a>=b)
# Out:
# True

# %%
a=45
b=2
print(a<=b)
# Out:
# False

# %%
a=45
b=2
print(a>b)
# Out:
# True

# %%
a=45
b=2
print(a==b)
# Out:
# False

# %%
a=45
b=2
print(a!=b)
# Out:
# True

# %%
a=45
b=2
a>=b
# Out:
# True

# %%
#bitwise operation : &,|,~,>>,<<,^
#& and
a=10
b=12
a&b
# Out:
# 8

# %%
#| or
a=10
b=12
a|b
# Out:
# 14

# %%
#~ nor
#~a = -(a+1)
a=10
b=12
~ a
#bin(a)
# Out:
# -11

# %%
#<< left shift
a=10
b=2
a<<b # shifts 2 bits to the left of 10 and add 0's ath the end
# Out:
# 40

# %%
#>> right shift
a=10
b=2
a>>b #shifts 2 bits to the right and discard them since no bits to the right
# Out:
# 2

# %%
# ^ ex or
a=10
b=12
a^b
# Out:
# 6

# %%
bin(10)
# Out:
# '0b1010'

# %%
#identity operators : is , is not
#compares the address stored in the variables

a='mynameisrekha'
b='mynameisrekha'
a is b
# Out:
# True

# %%
a='my name is rekha'
b='my name is rekha'
a is b
# Out:
# False

# %%
a=90
b=90
a is not b
# Out:
# False

# %%
a=500
b=500
a is b
# Out:
# False

# %%
a=256 # -5 to 256 is the range of int the address stored is same
b=256
a is b
# Out:
# True

# %%
a=-5
b=-5
a is b
# Out:
# True

# %%
#membership operator : in, not in
'a' in 'manish'
# Out:
# True

# %%
90 in 90
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 90 in 90
#
# TypeError: argument of type 'int' is not iterable

# %%
'a' not in 'manish'
# Out:
# False
