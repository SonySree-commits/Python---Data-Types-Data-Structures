# %% [markdown]
# STRINGS : ordered so allows indexing and slicing,
#           immutable

# %%
a='manish' #indexing
a[0]
# Out:
# 'm'

# %%
a[5]
# Out:
# 'h'

# %%
a[-2]
# Out:
# 's'

# %%
a[-1]
# Out:
# 'h'

# %% [raw]
# indexing can be in positive numbers like 0 to 5 or negative like -6 to -1 for example manish

# %%
a='manish'
a[0]+a[1]+a[2]
# Out:
# 'man'

# %%
a='manish'
a[-2]+a[-1]+a[-5]+a[-6]
# Out:
# 'sham'

# %%
a='manish' # can give both positive and negative indexing 
a[4]+a[-1]+a[-5]+a[0]
# Out:
# 'sham'

# %%
a='manish'
a[4]+a[-2]
# Out:
# 'ss'

# %%
a='manish' #slicing
a[0:3] #0 is start state and 3 is end state
       #default skip step is 1
# Out:
# 'man'

# %%
a='manish' #slicing
a[0:3:1] #0 is start state, 3 is end state , 1 is skip state
# Out:
# 'man'

# %%
a='manish'
a[0:5:2]
# Out:
# 'mns'

# %%
a='manish' 
a[0:5:2] # start state :end state : skip state   skipped 2 positions
# Out:
# 'mns'

# %%
a='karishma'
a[0:6:2]
# Out:
# 'krs'

# %%
a='karishma'
a[3:7] #default skip step is 1
# Out:
# 'ishm'

# %%
a='karishma'
a[:5] #default start sttate is 0
# Out:
# 'karis'

# %%
a='karishma'
a[:6000] #default end state is end of the string
# Out:
# 'karishma'

# %%
a='karishma'
a[: :]
# Out:
# 'karishma'

# %%
a='karishma' #movement is in left hand direction for negative indexing and right side for positive indexing
a[-1:-5:-2]
# Out:
# 'ah'

# %%
a='karishma' #positive start and negative skip state where the index goes to left and hence it cannot reach the end state so o/p is empty string 
a[2:-5:-1]
# Out:
# ''

# %%
a='karishma'
a[-2:2:-1]
# Out:
# 'mhsi'

# %%
a='karishma' # start is 1 and end is 6 but skip step is -1 so 1-1 is 0 moves left side and hence empty string is given as o/p
a[1:6:-1]
# Out:
# ''

# %%
a='christmas is around the corner' 
print(a[-9])
print(a[::2])
print(a[:5])
print(a[5:])
print(a[::-1]) #prints everything in reverse
print(a[-7:-3:-1])# from here everything  output will be blank
print(a[-7:23:1])
print(a[-7:23:-1])
print(a[23:-7:1])
print(a[23:-7:-1])
print(a[-7:-3:1])
# Out:
# h
# crsmsi rudtecre
# chris
# tmas is around the corner
# renroc eht dnuora si samtsirhc
#
#
#
#
#
#  cor

# %%
if =90
# Out:
#   Cell In[41], line 1
#     if =90
#        ^
# SyntaxError: invalid syntax

# %%
print = 90

# %%
print(90)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 print(90)
#
# TypeError: 'int' object is not callable

# %%
print(90) #restart kernel else we will get the error
# Out:
# 90

# %%
 #built in functions
a='manish is my name'
len(a)
# Out:
# 17

# %%
a='manish is my name'
a.count('m')
# Out:
# 3

# %%
help(str.count)
# Out:
# Help on method_descriptor:
#
# count(self, sub[, start[, end]], /) unbound builtins.str method
#     Return the number of non-overlapping occurrences of substring sub in string S[start:end].
#
#     Optional arguments start and end are interpreted as in slice notation.

# %%
help(len)
# Out:
# Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.

# %%
a= 'sony'
len(a) #gives the length of the variable
# Out:
# 4

# %%
a='sony sree'
a.count('s') #gives the count of the value given in the variable
# Out:
# 2

# %%
a='sony sree is a good girl'
a.upper() # converts the input string into upper case
# Out:
# 'SONY SREE IS A GOOD GIRL'

# %%
a='sony sree'
a.lower() # converts the input string into lower case
# Out:
# 'sony sree'

# %%
a='sony sree'
a.capitalize() # prints only the first letter in capital
# Out:
# 'Sony sree'

# %%
a='sony sree'
a.title() #prints the first letter of every word in capital
# Out:
# 'Sony Sree'

# %%
a='sony sree' 
a.find('e') #finds the position/ index of the input given in the variable but only gives the index of the first letter if there are multiple
            # for example if there are 2 e's only gives the index for the first 'e'
# Out:
# 7

# %%
a='sony sree'
a.find('s')
# Out:
# 0

# %%
a='sony sree'
a.find('o')
# Out:
# 1

# %%
a='sony sree' # if the given input is not found in the string then -1 is given as output
a.find('za')
# Out:
# -1

# %%
a='sony sree' #right find
a.rfind('e') #gives the index number of the element from the right
# Out:
# 2

# %%
a='sony sree'
a.index('n') #gives the index number of the input but only for the first one if there are 2 same letters same as find
#but if the given input is not found in the string then no output will be given it gives an error
# Out:
# 2

# %%
a='sony sree'
a.index('s')
# Out:
# 0

# %%
a='sony sree'
a.index('za')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 2
#       1 a='sony sree'
# ----> 2 a.index('za')
#
# ValueError: substring not found

# %%
a='sony sree'
a.replace('s', 'z') #replaces the values as given
# Out:
# 'zony zree'

# %%
a='sony sree'
a.replace('s', '#%z')  # the values changed is temporary not permanent so the replaced string is stored in different address
# Out:
# '#%zony #%zree'

# %%
a='sony sree is my name'
print(a.split()) #splits into words using space when no input is given
print(a.split('s')) #splits into strings from s till s whereever s is present
print(a.split('m')) #splits the sentence into strings like till m one string after m another string
# Out:
# ['sony', 'sree', 'is', 'my', 'name']
# ['', 'ony ', 'ree i', ' my name']
# ['sony sree is ', 'y na', 'e']

# %%
a='sonysree'
a.split()
# Out:
# ['sonysree']

# %%
a='sony sree'
print(a.strip()) #only first and last letters can be stripped 
print(a.strip('s'))
print(a.strip('e'))
print(a.strip('o')) #o is in the middle so cannot strip
print(a.strip('so'))
# Out:
# sony sree
# ony sree
# sony sr
# sony sree
# ny sree

# %%
a='sonysree2'
a.isdigit() #if the input string has numbers/digits gives true else false
# Out:
# False

# %%
a='092'
a.isdigit()
# Out:
# True

# %%
a='sonysree'#alphanumeric
a.isalpha() #if the input given contains only alphabets without numbers and space its given as true
# Out:
# True

# %%
a='sony sree'
a.isalpha()
# Out:
# False

# %%
a='sony0sree'
a.isalpha()
# Out:
# False

# %%
a='sony sree'
a.isalnum() # if the given input is alnum means combination of numbers and alphabets it's true else false
# Out:
# False

# %%
a='sony0sree'
a.isalnum()
# Out:
# True

# %%
a='sony sree'
a.endswith('z') #if it ends with the given input gives true else false
# Out:
# False

# %%
a='sony sree'
a.endswith('e')
# Out:
# True

# %%
a='sony sree'
a.startswith('s') #if it starts with the given input gives true else false
# Out:
# True

# %%
a='Sony Sree'
a.swapcase() # swaps the given case if caps given as input swaps into lower case and vice versa
# Out:
# 'sONY sREE'

# %%
a='sony sree'
b='%%%'  #adds the bunch of noise in the information
a.join(b) # joins each letter from b to whole sentence
# Out:
# '%sony sree%sony sree%'

# %%
a='NAME' #checks if the given input is in upper case
a.isupper()
# Out:
# True

# %%
a=' ' # checks if the string contains space
a.isspace()
# Out:
# True

# %%
a= "machine learning"
a.islower()
# Out:
# True

# %%
#29. Check whether the string "Deep Learning" follows title-case format.
a= "Deep Learning"
a.istitle()
# Out:
# True

# %%
#30. Check whether the string "data_science" is a valid identifier.
a="data_science" #identifier is the name of the variable
a.isidentifier()
# Out:
# True

# %%
a= '34rat56'
a.strip()
# Out:
# '34rat56'
